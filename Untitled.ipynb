// %%
TFile* results = new TFile("cmake-build-release/histograms.root","READ");


TH1F* ParticleDist = (TH1F*)results->Get("ParticleDist");
TH1F* MomentumDist =(TH1F*)results->Get("MomentumDist");

c = new TCanvas()

// %%
MomentumDist->Draw();

c->Draw()

// %%
ParticleDist->Draw();
c->Draw()
